# %% [markdown]
# ### Only 8 subjects appear to have any data gaps at all. Seems dropping any 10 sec chunks with less than full compliment of samples will result in minimal data loss.

# %%
import pandas as pd

FP = '/Users/bryanfry/code/activity-classifier/activity_classifier/EDA_output/EDA_01_check_gaps.csv'

# %%
df = pd.read_csv(FP)
df.sort_values(by='max_diff', ascending=False).head(20)
# Out:
#        file_name  n_samples   duration  max_diff  min_diff  \
# 96   P097.csv.gz   10180494  115740.00  13935.08      0.01
# 93   P094.csv.gz    5773541   66754.64   9019.25      0.01
# 59   P060.csv.gz    9144258   99821.56   8379.00      0.01
# 141  P142.csv.gz    5959687   66502.39   6905.54      0.01
# 7    P008.csv.gz    9585588  102600.00   6744.14      0.01
# 76   P077.csv.gz    8055045   86239.98   5689.55      0.01
# 15   P016.csv.gz    8874001   92340.00   3600.01      0.01
# 16   P017.csv.gz    9720001  100800.00   3600.01      0.01
# 108  P109.csv.gz    8820001   88200.00      0.01      0.01
# 97   P098.csv.gz   10530001  105300.00      0.01      0.01
# 98   P099.csv.gz    9000001   90000.00      0.01      0.01
# 99   P100.csv.gz   10440001  104400.00      0.01      0.01
# 100  P101.csv.gz    9624001   96240.00      0.01      0.01
# 101  P102.csv.gz    9000001   90000.00      0.01      0.01
# 102  P103.csv.gz    8820001   88200.00      0.01      0.01
# ...

# %%
df
# Out:
#        file_name  n_samples   duration  max_diff  min_diff  \
# 0    P001.csv.gz   10020001  100200.00      0.01      0.01
# 1    P002.csv.gz    8820001   88200.00      0.01      0.01
# 2    P003.csv.gz    9720001   97200.00      0.01      0.01
# 3    P004.csv.gz    7791785   77917.84      0.01      0.01
# 4    P005.csv.gz    9900001   99000.00      0.01      0.01
# ..           ...        ...        ...       ...       ...
# 146  P147.csv.gz    9720001   97200.00      0.01      0.01
# 147  P148.csv.gz    9510001   95100.00      0.01      0.01
# 148  P149.csv.gz    9060001   90600.00      0.01      0.01
# 149  P150.csv.gz    9630001   96300.00      0.01      0.01
# 150  P151.csv.gz   10770001  107700.00      0.01      0.01
#
#                                      diff_distribution
# 0    0.01    9619200\n0.01     400800\nName: count,...
# 1    0.01    8467200\n0.01     352800\nName: count,...
# 2    0.01    9331200\n0.01     388800\nName: count,...
# ...
